# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
DATA_PATH = './gui/'

# %%
SAMPLE_PATH = DATA_PATH+'2020_11_06_09_30_05 (1).png'
sample = cv2.imread(SAMPLE_PATH)

# %%
plt.rcParams["figure.figsize"] = (11, 6)
plt.imshow(sample[:,:,::-1])

# %% [markdown]
# ## Transform pipeline
#
# 1. Convert to Grayscale
# 2. Histogram transformation
# 3. Blur with Gaussian/Bilateral Filter
# 4. Convert to Binary img
# 5. Morphology operation to

# %%
gray = cv2.cvtColor(sample, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_transform, cmap="gray")

# %%
gray_transform = cv2.bilateralFilter(equ, d=13, sigmaColor=15, sigmaSpace=15)

# %% [markdown]
# ## METHOD 1:

# %%
blackAndWhiteImage = cv2.adaptiveThreshold(gray_transform, maxValue=255, 
                                                     adaptiveMethod=cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                                     thresholdType=cv2.THRESH_BINARY, blockSize=315, C=10)
plt.imshow(blackAndWhiteImage, cmap="gray")

# %%
reverse_color = (255-blackAndWhiteImage)
plt.imshow(reverse_color, cmap='gray')

# %%
erolation = cv2.erode(reverse_color, np.ones((3,3)), iterations=4)
fig, axs = plt.subplots(1, 2)
axs[0].imshow(reverse_color, cmap='gray')
axs[1].imshow(erolation, cmap='gray')

# %%
dilation = cv2.dilate(erolation, np.ones((3,3)), iterations=4)
fig, axs = plt.subplots(1, 2)
axs[0].imshow(erolation, cmap='gray')
axs[1].imshow(dilation, cmap='gray')

# %%
mask = (255-dilation)
plt.imshow(mask, cmap='gray')

# %%
contours, hierarchy = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
contours_filted = []
for contour in contours:
    area = cv2.contourArea(contour)
    
    if area > 5000:
        contours_filted.append(contour)
        
print(len(contours_filted))
# Out:
# 4

# %%
sample_copy = sample.copy()
plt.imshow(cv2.drawContours(sample_copy, contours_filted, -1, (0,255,0), 3))

# %% [markdown]
# ## METHOD 2:

# %%
plt.imshow(equ, cmap='gray')

# %%
fil = cv2.bilateralFilter(equ, 9, 15, 5, cv2.BORDER_DEFAULT);
plt.imshow(fil, cmap='gray')

# %%
edge = cv2.Canny(fil, 220, 240, 30)
plt.imshow(edge, cmap='gray')

# %%
lines = cv2.HoughLines(edge,1,np.pi/180, 250)
gray_copy = gray.copy()

for i in range(len(lines)):
    for r,theta in lines[i]: 
        # Stores the value of cos(theta) in a 
        a = np.cos(theta) 

        # Stores the value of sin(theta) in b 
        b = np.sin(theta) 

        # x0 stores the value rcos(theta) 
        x0 = a*r 

        # y0 stores the value rsin(theta) 
        y0 = b*r 

        # x1 stores the rounded off value of (rcos(theta)-1000sin(theta)) 
        x1 = int(x0 + 1000*(-b)) 

        # y1 stores the rounded off value of (rsin(theta)+1000cos(theta)) 
        y1 = int(y0 + 1000*(a)) 

        # x2 stores the rounded off value of (rcos(theta)+1000sin(theta)) 
        x2 = int(x0 - 1000*(-b)) 

        # y2 stores the rounded off value of (rsin(theta)-1000cos(theta)) 
        y2 = int(y0 - 1000*(a)) 

        # cv2.line draws a line in img from the point(x1,y1) to (x2,y2). 
        # (0,0,255) denotes the colour of the line to be  
        #drawn. In this case, it is red.  
        cv2.line(gray_copy,(x1,y1), (x2,y2), (0,0,255), 2) 

plt.imshow(gray_copy, cmap='gray')
